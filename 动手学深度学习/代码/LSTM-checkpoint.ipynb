# %%
from mxnet import autograd, nd, gluon
from mxnet.gluon import loss as gloss
import random
import utils
import time
import math
import zipfile

# %%
with zipfile.ZipFile('C:/Users/Administrator/DoDL/data/jaychou_lyrics.txt.zip') as zin:
    with zin.open('jaychou_lyrics.txt') as f:
        corpus_chars = f.read().decode('utf-8')
corpus_chars = corpus_chars.replace('\n',' ').replace('\r', ' ')
idx_to_char = list(set(corpus_chars))
char_to_idx = dict([(char, i) for i,char in enumerate(idx_to_char)])
vocab_size = len(char_to_idx)
corpus_indices = [char_to_idx[char] for char in corpus_chars]

# %%
def get_params():
    def _one(shape):
        return nd.random.normal(scale=0.01, shape=shape)
    
    def _three():
        return (_one((num_inputs, num_hiddens)),
               _one((num_hiddens, num_hiddens)),
               _one(num_hiddens))
    
    W_xi, W_hi, b_i = _three()
    W_xf, W_hf, b_f = _three()
    W_xo, W_ho, b_o = _three()
    W_xc, W_hc, b_c = _three()
    
    W_hq = _one((num_hiddens, num_outputs))
    b_q = _one(num_outputs)
    
    params = [W_xi, W_hi, b_i, W_xf, W_hf, b_f, W_xo, W_ho, b_o, W_xc, W_hc, b_c,
     W_hq, b_q]
    for param in params:
        param.attach_grad()
    return params

# %%
def init_lstm_state(batch_size, num_hidden):
    return (nd.zeros(shape=(batch_size, num_hidden)),
           nd.zeros(shape=(batch_size, num_hidden)))

# %%
def lstm(inputs, state, params):
    [W_xi, W_hi, b_i, W_xf, W_hf, b_f, W_xo, W_ho, b_o, W_xc, W_hc, b_c,
     W_hq, b_q] = params 
    (H, C) = state
    outputs = []
    
    for X in inputs:
        I = nd.sigmoid(nd.dot(X, W_xi) + nd.dot(H, W_hi) + b_i)
        F = nd.sigmoid(nd.dot(X, W_xf) + nd.dot(H, W_hf) + b_f)
        O = nd.sigmoid(nd.dot(X, W_xo) + nd.dot(H, W_ho) + b_o)
        C_tilda = nd.tanh(nd.dot(X, W_xc) + nd.dot(H, W_hc) + b_c)
        
        C = F * C + I * C_tilda
        H = O * C.tanh()
        Y = nd.dot(H, W_hq) + b_q
        outputs.append(Y)
    return outputs, (H, C)

# %%
def data_iter_random(corpus_indices, batch_size, num_steps):
    num_examples = (len(corpus_indices) - 1) // num_steps
    example_indices = list(set(num_examples))
    num_batch = num_examples //  batch_size
    random.shuffle(example_indices)
    
    def _data(pos):
        return corpus_indices[pos : pos + num_steps]
    
    for i in range(num_batches):
        i = i * batch_size
        batch_indices = example_indices[i : i + batch_size]
        X = [_data(j * num_steps) for j in batch_indices]
        Y = [_data(j * num_steps + 1) for j in batch_indices]
        yield nd.array(X), nd.array(Y)

# %%
def data_iter_consecutive(corpus_indices, batch_size, num_steps):
    corpus_indices = nd.array(corpus_indices)
    data_len = len(corpus_indices)
    batch_len = data_len // batch_size
    indices = corpus_indices[0 : batch_size*batch_len].reshape((batch_size,
                                                               batch_len))
    num_epochs = (batch_len-1) // num_steps
    for i in range(num_epochs):
        i = i * num_steps
        X = indices[:, i : i + num_steps]
        Y = indices[:, i+1 : i+num_steps+1]
        yield X, Y

# %%
def to_onehot(X, size):
    return [nd.one_hot(x, size) for x in X.T]

# %%
def grad_clipping(params, theta):
    norm = nd.array([0])
    for param in params:
        norm += (param.grad ** 2).sum()
    norm = norm.sqrt().asscalar()
    if norm > theta:
        for param in params:
            param.grad[:] *= theta / norm

# %%
def predict_rnn(prefix, pred_len, rnn, params, init_rnn_state, num_hiddens
               ,vocab_size, idx_to_char, char_to_idx):
    state = init_rnn_state(1, num_hiddens)
    output = [char_to_idx[prefix[0]]]
    for t in range(len(prefix) + pred_len - 1):
        X = to_onehot(nd.array([output[-1]]), vocab_size)
        (Y, state) = rnn(X, state, params)
        if t < len(prefix) - 1:
            output.append(char_to_idx[prefix[t+1]])
        else:
            output.append(int(Y[0].argmax(axis=1).asscalar()))
    return ''.join([idx_to_char[i] for i in output])

# %%
def train_and_predict_rnn(lstm, get_params, init_lstm_state, num_hiddens,
                         vocab_size, corpus_indices, idx_to_char, 
                         char_to_idx, is_random_iter, num_epochs, num_steps,
                         lr, clipping_theta, batch_size, pred_period, 
                         pred_len, prefixes):
    if is_random_iter:
        data_iter_fn = data_iter_random
    else:
        data_iter_fn = data_iter_consecutive
    params = get_params()
    loss = gloss.SoftmaxCrossEntropyLoss()
    
    for epoch in range(num_epochs):
        if not is_random_iter:
            state = init_lstm_state(batch_size, num_hiddens)
        l_sum, n, start = 0, 0, time.time()
        data_iter = data_iter_fn(corpus_indices, batch_size, num_steps)
        for X, Y in data_iter:
            if is_random_iter:
                state = init_lstm_state(batch_size, num_hiddens)
            else:
                for s in state:
                    s.detach()           
            with autograd.record():
                inputs = to_onehot(X, vocab_size)
                outputs, state = lstm(inputs, state, params)
                outputs = nd.concat(*outputs, dim=0)
                y = Y.T.reshape((-1, ))
                l = loss(outputs, y).mean()
            l.backward()
            grad_clipping(params, clipping_theta)
            utils.sgd(params, lr, 1)
            l_sum += l.asscalar() * y.size
            n += y.size
            
            if (epoch + 1) % pred_period == 0:
                print('epoch %d, perplexity %f, time %.2f sec' % (
                    epoch + 1, math.exp(l_sum / n), time.time() - start))
                for prefix in prefixes:
                    print(' -', predict_rnn(
                        prefix, pred_len, lstm, params, init_lstm_state,
                        num_hiddens, vocab_size, idx_to_char, char_to_idx))

# %%
num_epochs, num_steps, batch_size, lr, clipping_theta = 160, 35, 32, 1e2, 1e-2
num_inputs, num_hidden, num_outputs = vocab_size, 256, vocab_size
pred_period, pred_len, prefixes = 40, 50, ['分开', '不分开']
train_and_predict_rnn(lstm, get_params, init_lstm_state, num_hiddens,
                          vocab_size, corpus_indices, idx_to_char,
                          char_to_idx, False, num_epochs, num_steps, lr,
                          clipping_theta, batch_size, pred_period, pred_len,
                          prefixes)
# Out:
# epoch 40, perplexity 135.339943, time 2.49 sec
#  - 分开 我不能要你的样 我知道你的手 我知么这样个人 你说你说我的笑 你说的爱我知么 你说不能要人 我不能
#  - 不分开 你说你说我的手 你说的爱我 不要要为了 你说的爱 你说的很手 我说你的爱爱我 我的爱你已经你 你的
# epoch 40, perplexity 120.297406, time 5.50 sec
#  - 分开 我不能要你 我的世界 已经不是 我的感魂 已不是
#  - 不分开 我不能再想 我不能要你 你的爱情 我的世界 我们
# epoch 40, perplexity 116.221343, time 8.64 sec
#  - 分开 我不能要你的人 我说你的手 我不是你的笑 我说你的爱笑 我的笑笑不出 你说的爱我有多 你说你的爱
#  - 不分开 我不能再想 我不能再想 我不能再想 我的爱情 你笑的很空 我们的爱 我用了一直 我的爱情  让我不
# epoch 40, perplexity 108.511124, time 11.65 sec
#  - 分开 我不能要你 你的爱情 我不是一个 我的笑界 已经不是  我的爱情  不是你的  不要你的  我们
#  - 不分开 我不能再想 我不能再想 我不能再想 我不能再想 你的爱情 我们的感泪 我用你的爱 我不能再想 你的
# epoch 40, perplexity 106.351634, time 14.61 sec
#  - 分开 我想想你说 我有一种 都不用  我们一个  不是你的  不用
#  - 不分开 我不能再想 我没有一种 你说你 等兽人 的灵魂 我的公 我不懂   我的
# epoch 40, perplexity 102.853858, time 17.59 sec
#  - 分开 我用想在你的笑 我说你的爱笑 你说的爱我 我们的爱我 我不想你的笑 我说你的爱笑 你说的爱我 我知
#  - 不分开 你的爱情不能 你的爱我 在一个味道 我们的爱你 我们的爱你 你的世界 我都是一个 我的感道 你的爱
# epoch 40, perplexity 100.079479, time 20.66 sec
#  - 分开 我不能要你 你的爱 我不能再想 我不道理 你的爱的 我不能不见 你的爱情 已不了 我不能再想 我不
#  - 不分开 你的爱你已经我 你的爱你已经我 我不能要你 你不能再想 你的爱情 已不了 我不懂 我不再再 我不道
# epoch 40, perplexity 98.834730, time 23.71 sec
#  - 分开 我用拳 你离开 我的灵魂 都不了 我不能再烦了 我不能再想 我不能再想 我不能再烦了 我不能再想
#  - 不分开 我不能再想 我不能再想 我不能再烦了 我不能再想 我不能再想 我不能再烦了 我不能麻烦了 我不能麻
# epoch 40, perplexity 97.987900, time 26.84 sec
#  - 分开 我不能要你 我没有一个 我们的爱 我不用 你的爱 我的手 我不懂 我不能 我不了 我不了 我不了
#  - 不分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
# epoch 40, perplexity 96.977418, time 29.82 sec
#  - 分开 我不能要想开 我不能要想开 我不能要想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想
#  - 不分开 我不能再想 我不能再想 我不要再想我 我不是你的笑 我不会很想 我不能再想 我不能再想我 我不能再
# epoch 40, perplexity 94.770669, time 33.09 sec
#  - 分开 我不要要 你不要 我不要 我不要 我不要 我不要 我不要 我不要 我不要 我不要 我不要 我不要
#  - 不分开 我不能要再开 我不能再想 我不要再想 我不要再想 我不要再 我不要再想 我不要再 我不要再 我不要
# epoch 40, perplexity 93.978888, time 36.17 sec
#  - 分开 我只能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再 我不能 我不再 我不懂 我不
#  - 不分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再 我不
# epoch 40, perplexity 88.550717, time 73.04 sec
#  - 分开 我不能再 我不要再想 我不能再 我不要我 我不再再 我不能再 我不能再 我不能再 我不能再 我不能
#  - 不分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
# epoch 40, perplexity 88.167056, time 76.14 sec
#  - 分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
#  - 不分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
# epoch 40, perplexity 88.168904, time 79.44 sec
#  - 分开 我是我们 你不开 我不能 我不能 你
#  - 不分开 我不能再想 我不能再想 我不能再想 我不能 你 我
# epoch 40, perplexity 88.052688, time 82.80 sec
#  - 分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
#  - 不分开 我不能再想 我不能再想 我不能再想我不能 我不能这样 我不能再想 我不能再想 我不能再想 我不能再
# epoch 40, perplexity 88.267020, time 86.21 sec
#  - 分开 我不能再 我不能再想 我不能你的笑 我不能你 我不了 你怎么 太什么 太了
#  - 不分开 我不能再想 我不能再想 我不能这样 我不能再想 我不能你的笑 我不能你的笑 我不能你的笑 我不能这
# epoch 40, perplexity 88.480181, time 89.65 sec
#  - 分开 我不能再想 我不能 我不 我不 我不 我不 我不能 我不能 我不能 我不能 我不能 我不能 我不能
#  - 不分开 我不能再想 我不能再想 我不能 我不 我不能 我不能 我不能 我不能 我不能 我不能 我不能 我不
# epoch 40, perplexity 88.765329, time 93.15 sec
#  - 分开 我不能再想 我不能再想 我不能 我不 我不能 我不了 你说了 我不了 你不了 我不了 你不了 我不
#  - 不分开 我不能再想 我不能再想 我不能 我不了 我不能 我不了 你说了 我不了 你不了 我不了 你不了 我
# epoch 40, perplexity 88.707705, time 96.62 sec
#  - 分开 我不能再想 我不能再想 我不是你的笑 我们
#  - 不分开 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我不能再想 我
# epoch 40, perplexity 88.511171, time 100.23 sec
#  - 分开 我想想你的手 我知道你 你不好 我不能 我不了 你的爱 我不了 我不了 你的爱
#  - 不分开 我不能再想 我不能再想 我不能这样 我不能 我不了 我不了 你说了 我不了 我不了 你不了 我不了
# epoch 40, perplexity 88.798267, time 103.63 sec
#  - 分开 我不能再想 我不能再想 我不能这样手 我不能 你不开了我 不能不能 我不了 我不能 我不了 我不了
#  - 不分开 我不能再想 我不能再想 我不能这样手 我不能 我不要再想 我不能 我不了 我不能 我不了 你说了
# epoch 40, perplexity 88.936336, time 107.26 sec
#  - 分开 我想想你的手 我想想你的笑 我不想再想 我不能再想我 不想你的手 我知么觉 你已经不开 你的爱爱
#  - 不分开 我知道你 我不要我 我不能再想我 不知觉 你怎么我 不知么 你说了 我不能 我不了 我不了 我不了
# epoch 40, perplexity 88.842630, time 110.32 sec
#  - 分开 我不能觉 你的世界 不是我 我不懂 你的生界 我不懂 你不了 你的爱爱 我不懂 你不了 你的爱爱
#  - 不分开 我不能不想 你的爱情 你说了 我不了 你的爱 我不能 我不了 你的爱 我不能 我不了 你的爱 我不
# epoch 40, perplexity 90.969679, time 147.16 sec
#  - 分开 我可以你的手 我们的感 你的世 我不懂 你不见 你的爱 我不懂 我不懂 你的爱 我不懂 你不见 你
#  - 不分开 我不能再想 我不能要你 我不能 你不是我不能 我不能 你不是我不能 不知道 你不会 我不能 我不要
# epoch 40, perplexity 90.869406, time 150.31 sec
#  - 分开 我可以你的手 我说你的爱 我不该你的爱 我说你的爱爱 你说的爱我 我在你的很惑 我说你的爱爱 你说
#  - 不分开 我不能再想 我不能 不要我 我不要 我不要 我不要 我不要 我不能 我不了 我不了 我不了 你说了
# epoch 40, perplexity 90.940599, time 153.37 sec
#  - 分开 我可以觉 你的世界 你说的爱 我不用够 你说了爱你 我的世界 你不开 不是一烦了 我用爱你 不是我
#  - 不分开 我不能再想 我不要这样 我不想要你 我不能要你 我不能要不见 我不能不想 你不能要我 我不想要你
# epoch 40, perplexity 91.406825, time 156.45 sec
#  - 分开 我不能要我的手 我说你的爱 我不是你的爱 我说你的爱 我不是你的爱 我说你的爱 我不是你的爱 我说
#  - 不分开 我不能再想 我不要再想我 我不能 我不是我不见 我不能 我不了 我不了 我不了 不要我的手 我说了
# epoch 40, perplexity 92.162112, time 159.48 sec
#  - 分开 我不能再想 我没有你的手 我说你的笑 我不是你的爱 我说你的爱 我不是你的爱 我说你的爱 我不是你
#  - 不分开 我不能再想 我不要这样手 我不能说你的手 我知么这样 你说你的爱 我不是这样 我不能要你 我不能这
# epoch 40, perplexity 92.592446, time 162.56 sec
#  - 分开 我可以 你的手 我们的感节 我的笑界 你的世界 我的世界 我不够 我不能 我不再 我不了 我不能
#  - 不分开 我不能 你不开我有你的手 我知么 你不要我有你的手 你说你的手手 不要要我的样笑 我知么你的样笑
# epoch 40, perplexity 92.922981, time 165.80 sec
#  - 分开 我不是你的手 你说的爱笑 我们的世界 我用的世界 我们的世界 我们的世界 我们的世界 我们的世界
#  - 不分开 我不能这样 你的世界 我们的感界 我们的世界 我们的世界 我的世界 我不是不见 你的爱情 我的世界
# epoch 40, perplexity 92.925750, time 169.02 sec
#  - 分开 我不能要我们 我不能不该 你的爱情 我们 不是一直 我的爱情 不是不不见 你的爱情 我不懂 你不要
#  - 不分开 我不能再想 我不能要不见 我的爱你已经不是我 不要你说我的手 你说的爱情 我们的爱你 不用麻 我不
# epoch 40, perplexity 93.012504, time 172.09 sec
#  - 分开 我不能要不开 你的爱情 我不是够 你的爱爱 我的爱觉 你不开 不能要烦了 我不能再想 我不能再想
#  - 不分开 我不能再想 我不能再想 我不能这样 我不能够不见 你的爱爱你已经不到 我不能要不能要要你 我不能这
# epoch 40, perplexity 93.388003, time 175.15 sec
#  - 分开 我的爱你已开 你的眼界 用一个人 我们等感  没有一直 我的世界 我不懂 你不够 你的爱爱我 我的
#  - 不分开 我不能再想 我不能要你 你说你的手 我知么很人 你的爱爱你 我的世界 我不是够  我们一直 你的世
# epoch 80, perplexity 28.172726, time 2.35 sec
#  - 分开 我可以够 小世界 让一个人的姿望 默不着 一个人 我的爱情 沉着
#  - 不分开 你的发觉 太家 我一直一直再心 我一起 你会开 你的灵魂 从滚
# epoch 80, perplexity 21.395519, time 5.14 sec
#  - 分开 我可以够 小的一天 一直一起 我的感觉 你不回 你的爱情 我的感觉 已经没有没人 我等你 手指放风
#  - 不分开 你的是陪你 我不是你 你已经难重重 我的好好不出   我跟你  我不要  我不要听  你说你不要
# epoch 80, perplexity 20.424230, time 7.97 sec
#  - 分开 我可以够 小身一起 你的感觉 还不回 你说你 从来不对 你的那变 一么四 我焚格 都不回 你的灵魂
#  - 不分开 你的是不该 你不该 你已经爱难活 我不会说你们 有些人是一个人 我说不到 你说了离开不该 只是一种
# epoch 80, perplexity 19.257213, time 10.86 sec
#  - 分开 我可以够 小什么 你一直一直调 心气  不用听  把滚  丢滚  為滚 不可来
#  - 不分开 你的是陪你 我不是你 我想要这样牵着 后知不觉不该 这些会太太我的感觉 你说我爱你 让我那里 虽不
# epoch 80, perplexity 18.499365, time 13.65 sec
#  - 分开 我可以够 我微微有 你的感声 用不了 在谁中中 我的爱情 不不需不见 你说你 我手指 我的指 变单
#  - 不分开 你的我不会太多 我不能   我跟
# epoch 80, perplexity 18.126414, time 16.58 sec
#  - 分开 我可以够 小微的 幸福　 我的爱情 再想一口 我的感觉 这里都不对我 我手   我不出听我的 节音
#  - 不分开 你的是我怎么太好 一直我 说不到  你的眼子 说了没有多快  你说不出你   你就当一个特   这
# epoch 80, perplexity 17.548581, time 19.48 sec
#  - 分开 你可以我们的笑 你想笑的让我知道 你的爱是你就知道 你说不会想想要一点奖 我的表情是你  坚持就依
#  - 不分开 你的爱情像太快 也是不该再开错都为为了一种 会不会不让我的感爱你 这样是人的承号 那里我在等待 一
# epoch 80, perplexity 17.602810, time 22.37 sec
#  - 分开 我可以够 我的微笑 用雨一起 梦好后 一直小 我好变 我却不懂 我的指变 已经放着我的手都 你说我
#  - 不分开 你的爱情已太快 时间也不再要好好 我知道这样手 你说不见你 有些福的梦爱你 是你说的背惑 这些会会
# epoch 80, perplexity 17.607443, time 25.14 sec
#  - 分开 你可以我们 这样心着 分笑的画 我要一直解 我的世界 已经不了 不好麻 我爱你 说好难的 不怎么
#  - 不分开 你的是我怎么太快 我们都始不开来 我知道好好开开 我的爱你 经不开有重泪 我不起解动了天 我们不掉
# epoch 80, perplexity 17.648603, time 27.91 sec
#  - 分开 我可以够 我的世界 用沉时的眼面 谁说你的泪 音你在一遍 在天中的回忆 你说你爱我 有魔标的时间
#  - 不分开 你的我不会就开 最后的快快 我想好 你离开 有人的 我福了 说你说 你说的 我怎么这样心着你的手
# epoch 80, perplexity 17.246666, time 30.66 sec
#  - 分开 我可以够 你微身有 我的感觉 这么了 我都不够 你说一生的我就 分出 时出里的我 我在你们的世界
# epoch 80, perplexity 15.709636, time 64.32 sec
#  - 分开 我可以够呆着你的身丑 我轻轻一种一口 你说不见我 没有什么太多 我只是你说 有不是你怎么 不知不觉
#  - 不分开 你说不是我们的痛 也是我说了个手 不知不觉 我已经已已开 不知不觉 我已经这节活 后知么觉 你已开
# epoch 80, perplexity 15.786034, time 67.14 sec
#  - 分开 我可以够 我的笑笑 有些时间 梦一个向 我的感 我不了 不再 我的爱情 说了了雨 不是不要 你说你
#  - 不分开 你的回不能就开 没有了最生的手 我说你说好 有些没有太知要 你说一直好离开 我也不是我们笑着 为什
# epoch 80, perplexity 15.869630, time 69.89 sec
#  - 分开了我 一路 雨着之光的溪光 你在你离开的口 你说了是我 就得很你的温容 你说你已经过过 不该不会为我
#  - 不分开 你说不是不开 也不会会开开 你已经不开我也不要你 你已经我不开 我不能不到 我不会听我 我不要你的
# epoch 80, perplexity 15.830376, time 72.73 sec
#  - 分开了我 一路 雨破之外的溪光 一直好好来 我的世界被被太摧 我满头 北情放 你好的我面了 干着你 我不
#  - 不分开 你说我不会难过 我不是你们经开不想要烦了 我知道这样子 让你心着你 如果是我用 再有一种 我的世间
# epoch 80, perplexity 15.737749, time 75.53 sec
#  - 分开不能要我 在我们 你看看我的人说 你是我不是我的手 就要你爱爱不是 别是我们 不是得为我不知道 我发
#  - 不分开 你说我怎道开我会会 我的手 你已经开 我知道你说我没有错 我知道你的微笑我还能 我手记记离离 不是
# epoch 80, perplexity 15.596349, time 78.35 sec
#  - 分开 我可以再开 我的
#  - 不分开 你的回开我已经 甩着我的手面 你说你好好过过 那么福的太觉 你说不好承诺 已经的把我 不让得好 一
# epoch 80, perplexity 15.617173, time 81.28 sec
#  - 分开了我 一路 雨破之外的溪面 一路有一直就 老着那一天的秋边 我不是这个牵着你的爱觉 你不想想这个人
#  - 不分开 你的是我怎么太快 不要我 我不开 我不能再知道你说你 你已经开不开 我要后觉离开 我不是这样活着你
# epoch 80, perplexity 15.753871, time 84.38 sec
#  - 分开 我可以再开 我的 你 不需 这些  想你 爱好 爱 不来
#  - 不分开 你的是我怎么快 不该承 我怎么这个人 这么后觉觉错过 是别人的太多 我知么 不好 我不想这个牵着
# epoch 80, perplexity 15.856736, time 87.10 sec
#  - 分开不能 让我牵着这日雨 我说不到 为什么太开我 你的  啊不快太开 不该不该 你笑了离开我 不知不觉
#  - 不分开 你的是我怎么太不要 别单你说我的难难 你说我的很手 不该在在远旁的温容　 我说的爱情 当你那的味气
# epoch 80, perplexity 15.860538, time 89.91 sec
#  - 分开 我可以你的样笑我在微笑 你想想这样的美 我不能不了个我会不知不觉 你已经过不到 我不能在远 我不想
#  - 不分开 你的是我怎么我不知  不再 不想  我们  我有  说了一出对着 后后有后说我有一点人 我会会让我
# epoch 80, perplexity 15.699834, time 92.74 sec
#  - 分开 我可以你的样笑我在空面 爱我想想了 我不想要的笑 我知道好 你的爱觉 不知不觉 我就就这样的梦 在
#  - 不分开 你的是我怎么我 不知  我手
# epoch 80, perplexity 15.675867, time 95.56 sec
#  - 分开 我可以 你们 我想好这个人 后知后觉 又过了一起  后后   我爱上 哎色哎色 哎哟哎哟 喔故么
#  - 不分开 你的是我怎么我 不知  我我 这不好 说你的手经过了 麦麦已糖的风坡  我的手不出 我知道你的笑
# epoch 80, perplexity 15.615717, time 98.37 sec
#  - 分开了我 一路 雨着
#  - 不分开 你的是我已经不快 别快快快不多就是不要 我不想 你的我 不不该 我不要再开我 说你的手不快  不想
# epoch 80, perplexity 15.548854, time 101.09 sec
#  - 分开 我可以你的样笑着你 不是我 一定 三颗 是谁 在空  不来
#  - 不分开 你的是我已经不是我 太快 不是 不要的的样的不知道 爱我会想会手的手 这样不会 是那的梦福 就是我
# epoch 80, perplexity 15.466581, time 103.94 sec
#  - 分开 我可以你的样 我不想 你已经了离活 后在你的手活 不知不觉 我已经了离开 后知不觉 你已经离开不要
#  - 不分开 没有你叫我的是 你说了承乐 不该承为我的笑 只是我不觉觉 没有了离开 我就能不到 我们的爱情牵着
# epoch 80, perplexity 15.281549, time 106.69 sec
#  - 分开 我可以你的样 我不想 你已经离离活 我的手觉 默默 我想好 说你说
#  - 不分开 没有你的爱我不能够 我手经一口 不要会受得不起 我的一味的画徘 我很后再没人 这些 我们一个个人
# epoch 80, perplexity 15.222505, time 109.53 sec
#  - 分开 我可以你离开 我想着你的笑 我知道 你说了 我好了 这幸福后后过 后是糖果了 我有等了 一起 你说
#  - 不分开 我知道你离开 我也是 为远车 只有一起 再牵后 你说不要说 我知的感觉 后后后觉 我用一个牵着 心
# epoch 80, perplexity 15.251754, time 112.40 sec
#  - 分开 我可以 你的终 我不想 这些  幸果   好好 不想来 不要要 我不要再开我 我不是你的手 我知么
#  - 不分开 我知道你的笑我 不知要觉 我不想再想我我 说不要你已经我 说你    我
# epoch 80, perplexity 15.415696, time 115.21 sec
#  - 分开 我可以 你的终 我不想 这些  幸果             我不想你的把前啊 用转i  人a你的
#  - 不分开 我知道你的手我不要 你说我还不了吧 不要要我的 不要在这个牵着我的手 你当当我的手都 不让我的选口
# epoch 80, perplexity 15.583787, time 117.97 sec
#  - 分开 我可以你的样 我想想 你说我 我想难这 你的笑 已经不了 你说了 说好呢 你不懂 我不要 你说不是
#  - 不分开 我知道你的我一口 你说不是 我只要再牵不到 我不知觉 不要我不再不要说 你发你不想 不要
# epoch 80, perplexity 15.643933, time 120.79 sec
#  - 分开 我可以 你的终 我怎么 不好
#  - 不分开 你的是我不会太我 不知  我跟我  我有
# epoch 80, perplexity 15.767241, time 123.66 sec
#  - 分开 我可以 你的终 我怎么 不好
#  - 不分开 我知道这样牵着你 想不到 你说我  我
# epoch 80, perplexity 15.805391, time 126.41 sec
#  - 分开 我可以 你的终 我怎么 不好
#  - 不分开 没有再以我的表 一种一定在感自己 想不要你的笑度在一点味 我看不见你的手手 不要不该 我没有再离开
# epoch 80, perplexity 15.894685, time 129.25 sec
#  - 分开 我可以 你的终 我怎么 不好
#  - 不分开 没有再以我的世界 你说我的手手 不能够为我的想 在这么雨 我想是很快就是一种的路路 就想我
# epoch 80, perplexity 16.002497, time 132.00 sec
#  - 分开 我可以 你的世 有不是 你好了 泪了的 幸福呢 我懂了 不说了 爱淡了 梦福了 我懂了 不累
#  - 不分开 没有你的爱我 我都不着承着 不知开不了 有一种的时间 你说你离开 已经了离爱 我爱在你的世界 我说
# epoch 80, perplexity 16.087536, time 134.83 sec
#  - 分开 我可以 你的世 我不了 这些了 幸福了 后都不该 我心都能不能 你说你 我怎么这个牵着 后后啊 说
#  - 不分开 没有再以我的世界 你说我的很手 不能在在我的想容 你说我不爱 就是再是在乎 我也不到到你的脸 我想
# epoch 80, perplexity 16.044907, time 137.62 sec
#  - 分开 你可以我们 我不是你们 有
#  - 不分开 没有你对我的家 我说你说你手手 这么说的梦堡 我说你  我有我们快重你 说我一种生号 我说了 你们
# epoch 80, perplexity 16.063741, time 140.44 sec
#  - 分开了我可以 你的嘴像这样就抱乡开我不能要偏 就能放开我的天望你一种不到 没有这么太过 我只想在心身堡
#  - 不分开 没是我手 我没有再想 我知道你说你 说不能别不该 说不能太多 我一起 不需 不想
# epoch 80, perplexity 16.200476, time 143.26 sec
#  - 分开 我可以 你的微笑 我知道 你好不了 好好的 幸福呢 我好了 再咬 爱淡着 梦手了 开经了 不是不要
#  - 不分开 没有再以我的家 这么觉 说不觉 你的身笑 在窗里了梦 我们何感动了天 邀明月 让用用皎 啦儿无儿
# epoch 80, perplexity 16.397605, time 146.06 sec
#  - 分开了我 一路 你的时间 默默默无了 一种月 干了我 在一生 在炭了 有些了 有炭了 我们的爱情 一统
#  - 不分开 没有你对我我不是 我牵着 想要要我知想你 你说你 你手我已经你 你说你说你难笑 我不能不该 你说你
# epoch 80, perplexity 16.529272, time 148.87 sec
#  - 分开不能 我牵着这么子 你也悄不到你的笑 我知道一个很份 你说你说不多个人 怎么一直到我 你说你没有多笑
#  - 不分开 你的是是怎么太太 你说你 说不要再知道你的微 一定会好了可有你可以  一定是你的我的你们  我们的
# epoch 80, perplexity 16.636309, time 151.81 sec
#  - 分开了我可以 沉默的眼迹 在空地的画奈 不用 我手 这么人的 你在在梦  你想你离来 不用麻的梦 梦福的
#  - 不分开 你的是我怎么太快 别人我 说你看著 你看看地地地手 我说了 你说我
# epoch 80, perplexity 16.635283, time 154.96 sec
#  - 分开 我可以 你的很 我怎么 不好
#  - 不分开 没有你对我我没有自己 我想你 你的我不想 你说了 你说了没有多 我知道你的微笑 你说你在微方 只想
# epoch 80, perplexity 16.610067, time 157.79 sec
#  - 分开 我可以够 我的微笑 已 我在选里 众色地于 梦海盘 不用问 一起生的 从在梦身   你跟听  把离
#  - 不分开 你的是我怎么太快 看你躲 我不能再 说你的 幸福的梦笑 跟一种面面 我可以
# epoch 80, perplexity 16.683159, time 160.61 sec
#  - 分开 你可以 不要要烦了 不以麻烦了 让有一种等待 让我的等待 我的爱界不出来   你就当的选色 在我的
#  -
