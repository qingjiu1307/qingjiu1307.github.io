# %%
from mxnet import autograd, gluon, init, nd
from mxnet.gluon import data as gdata, loss as gloss, nn
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('C:/Users/Administrator/data/kaggle-house/train.csv')
test_data = pd.read_csv('C:/Users/Administrator/data/kaggle-house/test.csv')

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
#第一个指的是样本序号，第二个指的是特征
train_data.iloc[0:4, [0, 1, 2 ,3, -3, -2, -1 ]]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage SaleType SaleCondition  SalePrice
# 0   1          60       RL         65.0       WD        Normal     208500
# 1   2          20       RL         80.0       WD        Normal     181500
# 2   3          60       RL         68.0       WD        Normal     223500
# 3   4          70       RL         60.0       WD       Abnorml     140000

# %%
#将所有的训练数据和测试数据的79个特征按样本连结
all_features = pd.concat((train_data.iloc[:, 1:-1], test_data.iloc[:, 1: ]))

# %%
all_features.iloc[: 4, [0, 1, 2, 3, 4]]
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street
# 0          60       RL         65.0     8450   Pave
# 1          20       RL         80.0     9600   Pave
# 2          60       RL         68.0    11250   Pave
# 3          70       RL         60.0     9550   Pave

# %%
#object 指的是 string类型的特征
all_features.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
#                   ...
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# ...

# %% [markdown]
# ### 预处理数据
# 特征值在整个数据集上标准化，对于缺失的特征值，替换成该特征的均值

# %%
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
all_features[numeric_features] = all_features[numeric_features].apply(
    lambda x: (x - x.mean()) / (x.std()))
# 标准化后，每个特征的均值变为0，所以可以直接用0来替换缺失值
all_features[numeric_features] = all_features[numeric_features].fillna(0)

# %%
#接下来将离散数值转成指示特征。
#举个例子，假设特征MSZoning里面有两个不同的离散值RL和RM，那么这一步转换将去掉MSZoning特征，并新加两个特征MSZoning_RL和MSZoning_RM，其值为0或1。
#如果一个样本原来在MSZoning里的值为RL，那么有MSZoning_RL=1且MSZoning_RM=0。

# dummy_na=True将缺失值也当作合法的特征值并为其创建指示特征
all_features = pd.get_dummies(all_features, dummy_na=True)
all_features.shape
# Out:
# (2919, 331)

# %%
n_train = train_data.shape[0]
train_features = nd.array(all_features[:n_train].values)
test_features = nd.array(all_features[n_train:].values)
train_labels = nd.array(train_data.SalePrice.values).reshape((-1, 1))

# %%
#定义损失函数
loss = gloss.L2Loss()
#定义网络
def get_net():
    net = nn.Sequential()
    net.add(nn.Dense(50))
    net.add(nn.Dense(1))
    net.initialize(init=init.Xavier())
    return net

# %%
#对数均方根误差， 改成output 的log后求平方和求平均后开根号
def log_rmse(net, features, labels):
    #将小于1的值设为1， 使得取对数后更加稳定
    clipped_preds = nd.clip(net(features), 1, float('inf'))
    rmse = nd.sqrt(2 * loss(clipped_preds.log(), labels.log()).mean())
    return rmse.asscalar()

# %%
init.Constant?

# %%
def train(net, train_features, train_labels, test_features, test_labels,
         num_epochs, learning_rate, weight_decay, batch_size):
    train_ls, test_ls = [], []
    train_iter = gdata.DataLoader(gdata.ArrayDataset(
        train_features, train_labels), batch_size, shuffle=True)
    # 这里使用了Adam优化算法
    trainer = gluon.Trainer(net.collect_params(), 'adam', {
        'learning_rate': learning_rate, 'wd': weight_decay})
    for epoch in range(num_epochs):
        for X, y in train_iter:
            with autograd.record():
                l = loss(net(X), y)
            l.backward()
            trainer.step(batch_size)
        train_ls.append(log_rmse(net, train_features, train_labels))
        if test_labels is not None:
            test_ls.append(log_rmse(net, test_features, test_labels))
    return train_ls, test_ls

# %%
#K折交叉验证, 返回第i折交叉验证时所需要的训练和验证数据
def get_k_fold_data(k, i, X, y):
    assert k > 1
    fold_size = X.shape[0] // k
    X_train, y_train = None, None
    for j in range(k):
        idx = slice(j * fold_size, (j + 1) * fold_size)
        X_part, y_part = X[idx, :], y[idx]
        if j == i:
            X_valid, y_valid = X_part, y_part
        elif X_train is None:
            X_train, y_train = X_part, y_part
        else:
            X_train = nd.concat(X_train, X_part, dim=0)
            y_train = nd.concat(y_train, y_part, dim=0)
    return X_train, y_train, X_valid, y_valid

# %%
import utils

# %%
#在K折交叉验证中训练K次并返回训练和验证平均误差
def k_fold(k, X_train, y_train, num_epochs,
          learning_rate, weight_decay, batch_size):
    train_l_sum, valid_l_sum = 0, 0
    net = get_net()
    for i in range(k):
        data = get_k_fold_data(k, i, X_train, y_train)
        train_ls, valid_ls = train(net, *data, num_epochs, learning_rate,
                                   weight_decay, batch_size)
        train_l_sum += train_ls[-1]
        valid_l_sum += valid_ls[-1]
        if i == 0:
            utils.semilogy(range(1, num_epochs + 1), train_ls, 'epochs', 'rmse',
                         range(1, num_epochs + 1), valid_ls,
                         ['train', 'valid'])
        print('fold %d, train rmse %f, valid rmse %f'
              % (i, train_ls[-1], valid_ls[-1]))
    return train_l_sum / k, valid_l_sum / k

# %%
import time
k, num_epochs, lr, weight_decay, batch_size = 5, 100, 15, 0, 16
start = time.time()
train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr,
                          weight_decay, batch_size)
print('%d-fold validation: avg train rmse %f, avg valid rmse %f, cost time: %f'
      % (k, train_l, valid_l, (time.time() -start)))
# Out:
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# <ipython-input-137-eba5b93139a2> in <module>()
#       3 start = time.time()
#       4 train_l, valid_l = k_fold(k, train_features, train_labels, num_epochs, lr,
# ----> 5                           weight_decay, batch_size)
#       6 print('%d-fold validation: avg train rmse %f, avg valid rmse %f, cost time: %f'
#       7       % (k, train_l, valid_l, (time.time() -start)))
#
# <ipython-input-136-784174303fb9> in k_fold(k, X_train, y_train, num_epochs, learning_rate, weight_decay, batch_size)
#       7         data = get_k_fold_data(k, i, X_train, y_train)
#       8         train_ls, valid_ls = train(net, *data, num_epochs, learning_rate,
# ----> 9                                    weight_decay, batch_size)
#      10         train_l_sum += train_ls[-1]
#      11         valid_l_sum += valid_ls[-1]
#
# ...

# %%
def train_and_pred(train_features, test_features, train_labels, test_data,
                  num_epochs, lr, weight_decay, batch_size):
    net = get_net()
    train_ls, _ = train(net, train_features, train_labels, None, None,
                     num_epochs, lr, weight_decay, batch_size)
    utils.semilogy(range(1, num_epochs+1), train_ls, 'epochs', 'rmse')
    print('train rmse %f' % train_ls[-1])
    preds = net(test_features).asnumpy()
    test_data['SalePrice'] = pd.Series(preds.reshape(1, -1)[0])
    submission = pd.concat([test_data['Id'], test_data['SalePrice']], axis=1)
    submission.to_csv('submission.csv', index=False)

# %%
train_and_pred(train_features, test_features, train_labels, test_data,
               num_epochs, lr, weight_decay, batch_size)
# Out:
# train rmse 2.782738
